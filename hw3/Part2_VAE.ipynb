# %% [markdown]
# $$
# \newcommand{\mat}[1]{\boldsymbol {#1}}
# \newcommand{\mattr}[1]{\boldsymbol {#1}^\top}
# \newcommand{\matinv}[1]{\boldsymbol {#1}^{-1}}
# \newcommand{\vec}[1]{\boldsymbol {#1}}
# \newcommand{\vectr}[1]{\boldsymbol {#1}^\top}
# \newcommand{\rvar}[1]{\mathrm {#1}}
# \newcommand{\rvec}[1]{\boldsymbol{\mathrm{#1}}}
# \newcommand{\diag}{\mathop{\mathrm {diag}}}
# \newcommand{\set}[1]{\mathbb {#1}}
# \newcommand{\norm}[1]{\left\lVert#1\right\rVert}
# \newcommand{\pderiv}[2]{\frac{\partial #1}{\partial #2}}
# \newcommand{\bm}[1]{{\bf #1}}
# \newcommand{\bb}[1]{\bm{\mathrm{#1}}}
# $$
#
# # Part 2: Variational Autoencoder
# <a id=part2></a>

# %% [markdown]
# In this part we will learn to generate new data using a special type of autoencoder model which allows us to
# sample from it's latent space. We'll implement and train a VAE and use it to generate new images.

# %%
import unittest
import os
import sys
import pathlib
import urllib
import shutil
import re
import zipfile

import numpy as np
import torch
import matplotlib.pyplot as plt

# %load_ext autoreload
# %autoreload 2

# %%
test = unittest.TestCase()
plt.rcParams.update({'font.size': 12})
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using device:', device)
# Out:
# Using device: cuda

# %% [markdown]
# ### Obtaining the dataset
# <a id=part2_1></a>

# %% [markdown]
# Let's begin by downloading a dataset of images that we want to learn to generate.
# We'll use the [Labeled Faces in the Wild](http://vis-www.cs.umass.edu/lfw/) (LFW) dataset which contains many labels faces of famous individuals.
#
# We're going to train our generative model to generate a specific face, not just any face.
# Since the person with the most images in this dataset is former president George W. Bush, we'll set out to train a Bush Generator :)
#
# However, if you feel adventurous and/or prefer to generate something else, feel free to edit the `PART2_CUSTOM_DATA_URL` variable in `hw3/answers.py`.

# %%
import cs236781.plot as plot
import cs236781.download
from hw3.answers import PART2_CUSTOM_DATA_URL as CUSTOM_DATA_URL

DATA_DIR = pathlib.Path.home().joinpath('.pytorch-datasets')
if CUSTOM_DATA_URL is None:
    DATA_URL = 'http://vis-www.cs.umass.edu/lfw/lfw-bush.zip'
else:
    DATA_URL = CUSTOM_DATA_URL

_, dataset_dir = cs236781.download.download_data(out_path=DATA_DIR, url=DATA_URL, extract=True, force=False)
# Out:
# File C:\Users\User\.pytorch-datasets\lfw-bush.zip exists, skipping download.
# Extracting C:\Users\User\.pytorch-datasets\lfw-bush.zip...
# Extracted 531 to C:\Users\User\.pytorch-datasets\lfw/George_W_Bush

# %% [markdown]
# Create a `Dataset` object that will load the extraced images:

# %%
import torchvision.transforms as T
from torchvision.datasets import ImageFolder

im_size = 64
tf = T.Compose([
    # Resize to constant spatial dimensions
    T.Resize((im_size, im_size)),
    # PIL.Image -> torch.Tensor
    T.ToTensor(),
    # Dynamic range [0,1] -> [-1, 1]
    T.Normalize(mean=(.5,.5,.5), std=(.5,.5,.5)),
])

ds_gwb = ImageFolder(os.path.dirname(dataset_dir), tf)

# %% [markdown]
# OK, let's see what we got. You can run the following block multiple times to display a random subset of images from the dataset.

# %%
_ = plot.dataset_first_n(ds_gwb, 50, figsize=(15,10), nrows=5)
print(f'Found {len(ds_gwb)} images in dataset folder.')
# Out:
# Found 530 images in dataset folder.

# %%
x0, y0 = ds_gwb[0]
x0 = x0.unsqueeze(0).to(device)
print(x0.shape)

test.assertSequenceEqual(x0.shape, (1, 3, im_size, im_size))
# Out:
# torch.Size([1, 3, 64, 64])

# %% [markdown]
# ## The Variational Autoencoder
# <a id=part2_2></a>

# %% [markdown]
# An autoencoder is a model which learns a representation of data in an **unsupervised** fashion (i.e without any labels).
# Recall it's general form from the lecture:
#
# <img src="imgs/autoencoder.jpg"/>

# %% [markdown]
# An autoencoder maps an instance $\bb{x}$ to a **latent-space** representation $\bb{z}$.
# It has an encoder part, $\Phi_{\bb{\alpha}}(\bb{x})$ (a neural net with parameters $\bb{\alpha}$)
# and a decoder part, $\Psi_{\bb{\beta}}(\bb{z})$ (a neural net with parameters $\bb{\beta}$).
#
# While autoencoders can learn useful representations,
# generally it's hard to use them as generative models because there's no distribution we can sample from in the latent space. In other words, we have no way to choose a point $\bb{z}$ in the latent space
# such that $\Psi(\bb{z})$ will end up on the data manifold in the instance space.
#
# <img src="imgs/ae_sampling.jpg"/>

# %% [markdown]
# The variational autoencoder (VAE), first proposed by [Kingma and Welling](https://arxiv.org/pdf/1312.6114.pdf), addresses this issue by taking a probabilistic perspective.
# Briefly, a VAE model can be described as follows.
#
# We define, in Baysean terminology,
# - The **prior** distribution $p(\bb{Z})$ on points in the latent space.
# - The **likelihood** distribution of a sample $\bb{X}$ given a latent-space representation: $p(\bb{X}|\bb{Z})$.
# - The **posterior** distribution of points in the latent spaces given a specific instance: $p(\bb{Z}|\bb{X})$.
# - The **evidence** distribution $p(\bb{X})$ which is the distribution of the instance space due to the generative process.

# %% [markdown]
# To create our variational **decoder** we'll further specify:
#
# - A parametric likelihood distribution, $p _{\bb{\beta}}(\bb{X} | \bb{z}) = \mathcal{N}( \Psi _{\bb{\beta}}(\bb{z}) , \sigma^2 \bb{I} )$. The interpretation is that given a latent $\bb{z}$, we map it to a point normally distributed around the point calculated by our decoder neural network. Note that here $\sigma^2$ is a hyperparameter while $\vec{\beta}$ represents the network parameters.
# - A fixed latent-space prior distribution of $p(\bb{Z}) = \mathcal{N}(\bb{0},\bb{I})$.
#
# This setting allows us to generate a new instance $\bb{x}$ by sampling $\bb{z}$ from the multivariate normal
# distribution, obtaining the instance-space mean $\Psi _{\bb{\beta}}(\bb{z})$ using our decoder network,
# and then sampling $\bb{x}$ from $\mathcal{N}( \Psi _{\bb{\beta}}(\bb{z}) , \sigma^2 \bb{I} )$.

# %% [markdown]
# Our variational **encoder** will approximate the posterior with a parametric distribution
# $q _{\bb{\alpha}}(\bb{Z} | \bb{x}) =
# \mathcal{N}( \bb{\mu} _{\bb{\alpha}}(\bb{x}),  \mathrm{diag}\{ \bb{\sigma}^2_{\bb{\alpha}}(\bb{x}) \} )$.
# The interpretation is that our encoder neural network, $\Phi_{\vec{\alpha}}(\bb{x})$, calculates
# the mean and variance of the posterior distribution, and samples $\bb{z}$ based on them.
# An important nuance here is that our network can't contain any stochastic elements that
# depend on the model parameters, otherwise we won't be able to back-propagate to those parameters.
# So sampling $\bb{z}$ from $\mathcal{N}( \bb{\mu} _{\bb{\alpha}}(\bb{x}),  \mathrm{diag}\{ \bb{\sigma}^2_{\bb{\alpha}}(\bb{x}) \} )$ is not an option.
# The solution is to use what's known as the **reparametrization trick**: sample from an isotropic Gaussian,
# i.e. $\bb{u}\sim\mathcal{N}(\bb{0},\bb{I})$ (which doesn't depend on trainable parameters), and calculate the latent representation as
# $\bb{z} = \bb{\mu} _{\bb{\alpha}}(\bb{x}) + \bb{u}\odot\bb{\sigma}_{\bb{\alpha}}(\bb{x})$.

# %% [markdown]
# To train a VAE model, we would like to maximize the evidence, $p(\bb{X})$, because
# $
# p(\bb{X}) = \int p(\bb{X}|{\bb{z}})p(\bb{z})d\bb{z}
# $
# thus maximizing the likelihood of generated instances from over the entire latent space.
#
# The **VAE loss** can therefore be stated as minimizing $\mathcal{L} = -\mathbb{E}_{\bb{x}} \log p(\bb{X})$.
# As we saw in the lecture, this expectation is intractable,
# but we can obtain a lower-bound for $p(\bb{X})$ (the evidence lower bound, "ELBO"):
#
# $$
# \log p(\bb{X}) \ge \mathbb{E} _{\bb{z} \sim q _{\bb{\alpha}} }\left[ \log  p _{\bb{\beta}}(\bb{X} | \bb{z}) \right]
# -  \mathcal{D} _{\mathrm{KL}}\left(q _{\bb{\alpha}}(\bb{Z} | \bb{X})\,\left\|\, p(\bb{Z} )\right.\right)
# $$
#
# where
# $
# \mathcal{D} _{\mathrm{KL}}(q\left\|\right.p) =
# \mathbb{E}_{\bb{z}\sim q}\left[ \log \frac{q(\bb{Z})}{p(\bb{Z})} \right]
# $
# is the Kullback-Liebler divergence, which can be interpreted as the information gained by using the posterior $q(\bb{Z|X})$ instead of the prior distribution $p(\bb{Z})$.
#
# Using the ELBO, the VAE loss becomes,
# $$
# \mathcal{L}(\vec{\alpha},\vec{\beta}) = \mathbb{E} _{\bb{x}}  \left[
# \mathbb{E} _{\bb{z} \sim q _{\bb{\alpha}} }\left[ -\log  p _{\bb{\beta}}(\bb{x} | \bb{z}) \right]
# +  \mathcal{D} _{\mathrm{KL}}\left(q _{\bb{\alpha}}(\bb{Z} | \bb{x})\,\left\|\, p(\bb{Z} )\right.\right)
# \right].
# $$
#
# By remembering that the likelihood is a Gaussian distribution with a diagonal covariance and by applying the reparametrization trick, we can write the above as
#
# $$
# \mathcal{L}(\vec{\alpha},\vec{\beta}) = \mathbb{E} _{\bb{x}}  \left[
# \mathbb{E} _{\bb{z} \sim q _{\bb{\alpha}} }
# \left[
# \frac{1}{2\sigma^2}\left\| \bb{x}- \Psi _{\bb{\beta}}\left(  \bb{\mu} _{\bb{\alpha}}(\bb{x})  + \bb{\Sigma}^{\frac{1}{2}} _{\bb{\alpha}}(\bb{x}) \bb{u}   \right) \right\| _2^2
# \right]
# +  \mathcal{D} _{\mathrm{KL}}\left(q _{\bb{\alpha}}(\bb{Z} | \bb{x})\,\left\|\, p(\bb{Z} )\right.\right)
# \right].
# $$

# %% [markdown]
# ### Model Implementation
# <a id=part2_3></a>

# %% [markdown]
# Obviously our model will have two parts, an encoder and a decoder.
# Since we're working with images, we'll implement both as deep **convolutional** networks, where the decoder is a "mirror image" of the encoder implemented with adjoint (AKA transposed) convolutions.
# Between the encoder CNN and the decoder CNN we'll implement the sampling from
# the parametric posterior approximator $q_{\bb{\alpha}}(\bb{Z}|\bb{x})$
# to make it a VAE model and not just a regular autoencoder (of course, this is not yet enough to create a VAE,
# since we also need a special loss function which we'll get to later).

# %% [markdown]
# First let's implement just the CNN part of the Encoder network
# (this is not the full $\Phi_{\vec{\alpha}}(\bb{x})$ yet).
# As usual, it should take an input image and map to a activation volume of a specified depth.
# We'll consider this volume as the features we extract from the input image.
# Later we'll use these to create the latent space representation of the input.

# %% [markdown]
# **TODO**: Implement the `EncoderCNN` class in the `hw3/autoencoder.py` module.
# Implement any CNN architecture you like. If you need "architecture inspiration" you can see e.g. [this](https://arxiv.org/pdf/1512.09300.pdf) or [this](https://arxiv.org/pdf/1511.06434.pdf) paper.

# %%
import hw3.autoencoder as autoencoder

in_channels = 3
out_channels = 1024
encoder_cnn = autoencoder.EncoderCNN(in_channels, out_channels).to(device)
print(encoder_cnn)

h = encoder_cnn(x0)
print(h.shape)

test.assertEqual(h.dim(), 4)
test.assertSequenceEqual(h.shape[0:2], (1, out_channels))
# Out:
# EncoderCNN(
#   (cnn): Sequential(
#     (0): Sequential(
#       (0): Conv2d(3, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (1): LeakyReLU(negative_slope=0.2)
#       (2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): Sequential(
#       (0): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (1): LeakyReLU(negative_slope=0.2)
#       (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): Sequential(
#       (0): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (1): LeakyReLU(negative_slope=0.2)
#       (2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (3): Sequential(
#       (0): Conv2d(512, 1024, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     )
#   )
# )
# torch.Size([1, 1024, 4, 4])

# %% [markdown]
# Now let's implement the CNN part of the Decoder.
# Again this is not yet the full $\Psi _{\bb{\beta}}(\bb{z})$. It should take an activation volume produced
# by your `EncoderCNN` and output an image of the same dimensions as the Encoder's input was.
# This should be a CNN which is like a "mirror image" of the the Encoder. For example, replace convolutions with transposed convolutions, downsampling with up-sampling etc.
# Consult the documentation of [ConvTranspose2D](https://pytorch.org/docs/0.4.1/nn.html#convtranspose2d)
# to figure out how to reverse your convolutional layers in terms of input and output dimensions.

# %% [markdown]
# **TODO**: Implement the `DecoderCNN` class in the `hw3/autoencoder.py` module.

# %%
decoder_cnn = autoencoder.DecoderCNN(in_channels=out_channels, out_channels=in_channels).to(device)
print(decoder_cnn)
x0r = decoder_cnn(h)
print(x0r.shape)

test.assertEqual(x0.shape, x0r.shape)

# Should look like colored noise
T.functional.to_pil_image(x0r[0].cpu().detach())
# Out:
# DecoderCNN(
#   (cnn): Sequential(
#     (0): Sequential(
#       (0): ConvTranspose2d(1024, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     )
#     (1): Sequential(
#       (0): ConvTranspose2d(512, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (1): ReLU()
#       (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): Sequential(
#       (0): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (1): ReLU()
#       (2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (3): Sequential(
#       (0): ConvTranspose2d(128, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (1): ReLU()
#       (2): BatchNorm2d(3, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
# )
# torch.Size([1, 3, 64, 64])
# <PIL.Image.Image image mode=RGB size=64x64 at 0xD0192C8>

# %% [markdown]
# Let's now implement the full VAE Encoder, $\Phi_{\vec{\alpha}}(\vec{x})$.
# It will work as follows:
# 1. Produce a feature vector $\vec{h}$ from the input image $\vec{x}$.
# 2. Use two affine transforms to convert the features into the mean and log-variance of the posterior, i.e.
#     $$
#     \begin{align}
#         \bb{\mu} _{\bb{\alpha}}(\bb{x}) &= \vec{h}\mattr{W}_{\mathrm{h\mu}} + \vec{b}_{\mathrm{h\mu}} \\
#         \log\left(\bb{\sigma}^2_{\bb{\alpha}}(\bb{x})\right) &= \vec{h}\mattr{W}_{\mathrm{h\sigma^2}} + \vec{b}_{\mathrm{h\sigma^2}}
#     \end{align}
#     $$
# 3. Use the **reparametrization trick** to create the latent representation $\vec{z}$.
#
# Note that we model the **log** of the variance, not the actual variance.
# The reason is that the log is easier to optimize, since (a) It doesn't have to be positive, and (b) it has a much larger dynamic range.
# The above formulation is proposed in appendix C of the [VAE paper](https://arxiv.org/pdf/1312.6114.pdf).

# %% [markdown]
# **TODO**: Implement the `encode()` method in the `VAE` class within the `hw3/autoencoder.py` module.
# You'll also need to define your parameters in `__init__()`.

# %%
z_dim = 2
vae = autoencoder.VAE(encoder_cnn, decoder_cnn, x0[0].size(), z_dim).to(device)
print(vae)

z, mu, log_sigma2 = vae.encode(x0)

test.assertSequenceEqual(z.shape, (1, z_dim))
test.assertTrue(z.shape == mu.shape == log_sigma2.shape)

print(f'mu(x0)={list(*mu.detach().cpu().numpy())}, sigma2(x0)={list(*torch.exp(log_sigma2).detach().cpu().numpy())}')
# Out:
# VAE(
#   (features_encoder): EncoderCNN(
#     (cnn): Sequential(
#       (0): Sequential(
#         (0): Conv2d(3, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#         (1): LeakyReLU(negative_slope=0.2)
#         (2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#         (1): LeakyReLU(negative_slope=0.2)
#         (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#         (1): LeakyReLU(negative_slope=0.2)
#         (2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (3): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       )
#     )
#   )
#   (features_decoder): DecoderCNN(
#     (cnn): Sequential(
#       (0): Sequential(
#         (0): ConvTranspose2d(1024, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       )
#       (1): Sequential(
#         (0): ConvTranspose2d(512, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#         (1): ReLU()
#         (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): Sequential(
#         (0): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#         (1): ReLU()
#         (2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (3): Sequential(
#         (0): ConvTranspose2d(128, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#         (1): ReLU()
#         (2): BatchNorm2d(3, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (mu_net): Linear(in_features=16384, out_features=2, bias=True)
#   (log_sigma2_net): Linear(in_features=16384, out_features=2, bias=True)
#   (z_to_features): Linear(in_features=2, out_features=16384, bias=True)
# )
# mu(x0)=[-0.027129445, -0.5327138], sigma2(x0)=[0.6402869, 1.1027321]

# %% [markdown]
# Let's sample some 2d latent representations for an input image `x0` and visualize them.

# %%
# Sample from q(Z|x)
N = 500
Z = torch.zeros(N, z_dim)
_, ax = plt.subplots()
with torch.no_grad():
    for i in range(N):
        Z[i], _, _ = vae.encode(x0)
        ax.scatter(*Z[i].cpu().numpy())

# Should be close to the mu/sigma in the previous block above
print('sampled mu', torch.mean(Z, dim=0))
print('sampled sigma2', torch.var(Z, dim=0))
# Out:
# sampled mu tensor([-0.0122, -0.5442])
# sampled sigma2 tensor([0.7132, 1.1347])

# %% [markdown]
# Let's now implement the full VAE Decoder, $\Psi _{\bb{\beta}}(\bb{z})$.
# It will work as follows:
# 1. Produce a feature vector $\tilde{\vec{h}}$ from the latent vector $\vec{z}$ using an affine transform.
# 2. Reconstruct an image $\tilde{\vec{x}}$ from $\tilde{\vec{h}}$ using the decoder CNN.

# %% [markdown]
# **TODO**: Implement the `decode()` method in the `VAE` class within the `hw3/autoencoder.py` module.
# You'll also need to define your parameters in `__init__()`. You may need to also re-run the block above after you implement this.

# %%
x0r = vae.decode(z)

test.assertSequenceEqual(x0r.shape, x0.shape)

# %% [markdown]
# Our model's `forward()` function will simply return `decode(encode(x))` as well as the calculated mean and log-variance of the posterior.

# %%
x0r, mu, log_sigma2 = vae(x0)

test.assertSequenceEqual(x0r.shape, x0.shape)
test.assertSequenceEqual(mu.shape, (1, z_dim))
test.assertSequenceEqual(log_sigma2.shape, (1, z_dim))
T.functional.to_pil_image(x0r[0].detach().cpu())
# Out:
# <PIL.Image.Image image mode=RGB size=64x64 at 0x27A998C8>

# %% [markdown]
# ### Loss Implementation
# <a id=part2_4></a>

# %% [markdown]
# In practice, since we're using SGD, we'll drop the expectation over $\bb{X}$ and instead sample an instance from the training set and compute a point-wise loss. Similarly, we'll drop the expectation over $\bb{Z}$ by sampling from $q_{\vec{\alpha}}(\bb{Z}|\bb{x})$.
# Additionally, because the KL divergence is between two Gaussian distributions, there is a closed-form expression for it. These points bring us to the following point-wise loss:
#
# $$
# \ell(\vec{\alpha},\vec{\beta};\bb{x}) =
# \frac{1}{\sigma^2 d_x} \left\| \bb{x}- \Psi _{\bb{\beta}}\left(  \bb{\mu} _{\bb{\alpha}}(\bb{x})  +
# \bb{\Sigma}^{\frac{1}{2}} _{\bb{\alpha}}(\bb{x}) \bb{u}   \right) \right\| _2^2 +
# \mathrm{tr}\,\bb{\Sigma} _{\bb{\alpha}}(\bb{x}) +  \|\bb{\mu} _{\bb{\alpha}}(\bb{x})\|^2 _2 - d_z - \log\det \bb{\Sigma} _{\bb{\alpha}}(\bb{x}),
# $$
#
# where $d_z$ is the dimension of the latent space, $d_x$ is the dimension of the input and $\bb{u}\sim\mathcal{N}(\bb{0},\bb{I})$.
# This pointwise loss is the quantity that we'll compute and minimize with gradient descent.
# The first term corresponds to the data-reconstruction loss, while the second term corresponds to the KL-divergence loss.
# Note that the scaling by $d_x$ is not derived from the original loss formula and was added directly to the pointwise loss just to normalize the data term.

# %% [markdown]
# **TODO**: Implement the `vae_loss()` function in the `hw3/autoencoder.py` module.

# %%
from hw3.autoencoder import vae_loss
torch.manual_seed(42)

def test_vae_loss():
    # Test data
    N, C, H, W = 10, 3, 64, 64 
    z_dim = 32
    x  = torch.randn(N, C, H, W)*2 - 1
    xr = torch.randn(N, C, H, W)*2 - 1
    z_mu = torch.randn(N, z_dim)
    z_log_sigma2 = torch.randn(N, z_dim)
    x_sigma2 = 0.9
    
    loss, _, _ = vae_loss(x, xr, z_mu, z_log_sigma2, x_sigma2)
    
    test.assertAlmostEqual(loss.item(), 58.3234367, delta=1e-3)
    return loss

test_vae_loss()
# Out:
# tensor(58.3234)

# %% [markdown]
# ### Sampling
# <a id=part2_5></a>

# %% [markdown]
# The main advantage of a VAE is that it can by used as a generative model by sampling the latent space, since
# we optimize for a isotropic Gaussian prior $p(\bb{Z})$ in the loss function. Let's now implement this so that we can visualize how our model is doing when we train.

# %% [markdown]
# **TODO**: Implement the `sample()` method in the `VAE` class within the `hw3/autoencoder.py` module.

# %%
samples = vae.sample(5)
_ = plot.tensors_as_images(samples)

# %% [markdown]
# ### Training
# <a id=part2_6></a>

# %% [markdown]
# Time to train!

# %% [markdown]
# **TODO**:
# 1. Implement the `VAETrainer` class in the `hw3/training.py` module. Make sure to implement the `checkpoints` feature of the `Trainer` class if you haven't done so already in Part 1.
# 2. Tweak the hyperparameters in the `part2_vae_hyperparams()` function within the `hw3/answers.py` module.

# %%
import torch.optim as optim
from torch.utils.data import random_split
from torch.utils.data import DataLoader
from torch.nn import DataParallel
from hw3.training import VAETrainer
from hw3.answers import part2_vae_hyperparams

torch.manual_seed(42)

# Hyperparams
hp = part2_vae_hyperparams()
batch_size = hp['batch_size']
h_dim = hp['h_dim']
z_dim = hp['z_dim']
x_sigma2 = hp['x_sigma2']
learn_rate = hp['learn_rate']
betas = hp['betas']

# Data
split_lengths = [int(len(ds_gwb)*0.9), int(len(ds_gwb)*0.1)]
ds_train, ds_test = random_split(ds_gwb, split_lengths)
dl_train = DataLoader(ds_train, batch_size, shuffle=True)
dl_test  = DataLoader(ds_test,  batch_size, shuffle=True)
im_size = ds_train[0][0].shape

# Model
encoder = autoencoder.EncoderCNN(in_channels=im_size[0], out_channels=h_dim)
decoder = autoencoder.DecoderCNN(in_channels=h_dim, out_channels=im_size[0])
vae = autoencoder.VAE(encoder, decoder, im_size, z_dim)
vae_dp = DataParallel(vae).to(device)

# Optimizer
optimizer = optim.Adam(vae.parameters(), lr=learn_rate, betas=betas)

# Loss
def loss_fn(x, xr, z_mu, z_log_sigma2):
    return autoencoder.vae_loss(x, xr, z_mu, z_log_sigma2, x_sigma2)

# Trainer
trainer = VAETrainer(vae_dp, loss_fn, optimizer, device)
checkpoint_file = 'checkpoints/vae'
checkpoint_file_final = f'{checkpoint_file}_final'
if os.path.isfile(f'{checkpoint_file}.pt'):
    os.remove(f'{checkpoint_file}.pt')

# Show model and hypers
print(vae)
print(hp)
# Out:
# VAE(
#   (features_encoder): EncoderCNN(
#     (cnn): Sequential(
#       (0): Sequential(
#         (0): Conv2d(3, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#         (1): LeakyReLU(negative_slope=0.2)
#         (2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#         (1): LeakyReLU(negative_slope=0.2)
#         (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#         (1): LeakyReLU(negative_slope=0.2)
#         (2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (3): Sequential(
#         (0): Conv2d(512, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       )
#     )
#   )
#   (features_decoder): DecoderCNN(
#     (cnn): Sequential(
#       (0): Sequential(
#         (0): ConvTranspose2d(32, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       )
#       (1): Sequential(
#         (0): ConvTranspose2d(512, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#         (1): ReLU()
#         (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): Sequential(
#         (0): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#         (1): ReLU()
#         (2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (3): Sequential(
#         (0): ConvTranspose2d(128, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#         (1): ReLU()
#         (2): BatchNorm2d(3, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (mu_net): Linear(in_features=512, out_features=10, bias=True)
#   (log_sigma2_net): Linear(in_features=512, out_features=10, bias=True)
#   (z_to_features): Linear(in_features=10, out_features=512, bias=True)
# )
# {'batch_size': 1, 'h_dim': 32, 'z_dim': 10, 'x_sigma2': 1.0, 'learn_rate': 0.0001, 'betas': (0.9, 0.999)}

# %% [markdown]
# **TODO**:
# 1. Run the following block to train. It will sample some images from your model every few epochs so you can see the progress.
# 2. When you're satisfied with your results, rename the checkpoints file by adding `_final`. When you run the `main.py` script to generate your submission, the final checkpoints file will be loaded instead of running training. Note that your final submission zip will not include the `checkpoints/` folder. This is OK.

# %%
import IPython.display

def post_epoch_fn(epoch, train_result, test_result, verbose):
    # Plot some samples if this is a verbose epoch
    if verbose:
        samples = vae.sample(n=5)
        fig, _ = plot.tensors_as_images(samples, figsize=(6,2))
        IPython.display.display(fig)
        plt.close(fig)

if os.path.isfile(f'{checkpoint_file_final}.pt'):
    print(f'*** Loading final checkpoint file {checkpoint_file_final} instead of training')
    checkpoint_file = checkpoint_file_final
else:
    res = trainer.fit(dl_train, dl_test,
                      num_epochs=200, early_stopping=20, print_every=10,
                      checkpoints=checkpoint_file,
                      post_epoch_fn=post_epoch_fn)
    
# Plot images from best model
saved_state = torch.load(f'{checkpoint_file}.pt', map_location=device)
vae_dp.load_state_dict(saved_state['model_state'])
print('*** Images Generated from best model:')
fig, _ = plot.tensors_as_images(vae_dp.module.sample(n=15), nrows=3, figsize=(6,6))
# Out:
# --- EPOCH 1/200 ---
# train_batch (Avg. Loss 1.666, Accuracy 345.4): 100%|█████████████| 477/477 [00:28<00:00, 16.59it/s]
# test_batch (Avg. Loss 1.776, Accuracy 380.1): 100%|████████████████| 53/53 [00:00<00:00, 85.62it/s]
# train_batch (Avg. Loss 0.854, Accuracy 387.3): 100%|█████████████| 477/477 [00:29<00:00, 16.37it/s]
# test_batch (Avg. Loss 0.822, Accuracy 392.3): 100%|████████████████| 53/53 [00:00<00:00, 77.37it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 2
# train_batch (Avg. Loss 0.634, Accuracy 400.1): 100%|█████████████| 477/477 [00:28<00:00, 16.46it/s]
# test_batch (Avg. Loss 0.574, Accuracy 394.8): 100%|████████████████| 53/53 [00:00<00:00, 84.66it/s]
# train_batch (Avg. Loss 0.551, Accuracy 407.1): 100%|█████████████| 477/477 [00:28<00:00, 16.60it/s]
# test_batch (Avg. Loss 0.660, Accuracy 402.3): 100%|████████████████| 53/53 [00:00<00:00, 84.93it/s]
# train_batch (Avg. Loss 0.468, Accuracy 411.6): 100%|█████████████| 477/477 [00:28<00:00, 16.58it/s]
# test_batch (Avg. Loss 0.451, Accuracy 402.4): 100%|████████████████| 53/53 [00:00<00:00, 85.20it/s]
# train_batch (Avg. Loss 0.420, Accuracy 416.0): 100%|█████████████| 477/477 [00:28<00:00, 16.63it/s]
# test_batch (Avg. Loss 0.432, Accuracy 406.9): 100%|████████████████| 53/53 [00:00<00:00, 85.20it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 6
# train_batch (Avg. Loss 0.402, Accuracy 419.7): 100%|█████████████| 477/477 [00:28<00:00, 16.63it/s]
# test_batch (Avg. Loss 0.429, Accuracy 409.9): 100%|████████████████| 53/53 [00:00<00:00, 85.76it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 7
# train_batch (Avg. Loss 0.392, Accuracy 422.7): 100%|█████████████| 477/477 [00:28<00:00, 16.59it/s]
# test_batch (Avg. Loss 0.349, Accuracy 409.6): 100%|████████████████| 53/53 [00:00<00:00, 85.76it/s]
# train_batch (Avg. Loss 0.322, Accuracy 424.5): 100%|█████████████| 477/477 [00:28<00:00, 16.63it/s]
# test_batch (Avg. Loss 0.348, Accuracy 414.7): 100%|████████████████| 53/53 [00:00<00:00, 81.91it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 9
# train_batch (Avg. Loss 0.314, Accuracy 428.8): 100%|█████████████| 477/477 [00:28<00:00, 16.59it/s]
# test_batch (Avg. Loss 0.332, Accuracy 418.0): 100%|████████████████| 53/53 [00:00<00:00, 85.20it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 10
# --- EPOCH 11/200 ---
# train_batch (Avg. Loss 0.313, Accuracy 430.8): 100%|█████████████| 477/477 [00:28<00:00, 16.59it/s]
# test_batch (Avg. Loss 0.315, Accuracy 421.5): 100%|████████████████| 53/53 [00:00<00:00, 85.07it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 11
# train_batch (Avg. Loss 0.298, Accuracy 434.0): 100%|█████████████| 477/477 [00:28<00:00, 16.62it/s]
# test_batch (Avg. Loss 0.390, Accuracy 422.4): 100%|████████████████| 53/53 [00:00<00:00, 86.03it/s]
# train_batch (Avg. Loss 0.291, Accuracy 435.1): 100%|█████████████| 477/477 [00:28<00:00, 16.63it/s]
# test_batch (Avg. Loss 0.315, Accuracy 427.6): 100%|████████████████| 53/53 [00:00<00:00, 86.31it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 13
# train_batch (Avg. Loss 0.283, Accuracy 437.3): 100%|█████████████| 477/477 [00:28<00:00, 16.68it/s]
# test_batch (Avg. Loss 0.311, Accuracy 424.1): 100%|████████████████| 53/53 [00:00<00:00, 86.03it/s]
# train_batch (Avg. Loss 0.277, Accuracy 438.2): 100%|█████████████| 477/477 [00:28<00:00, 16.64it/s]
# test_batch (Avg. Loss 0.309, Accuracy 427.1): 100%|████████████████| 53/53 [00:00<00:00, 85.07it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 15
# train_batch (Avg. Loss 0.276, Accuracy 439.5): 100%|█████████████| 477/477 [00:28<00:00, 16.61it/s]
# test_batch (Avg. Loss 0.290, Accuracy 430.8): 100%|████████████████| 53/53 [00:00<00:00, 85.89it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 16
# train_batch (Avg. Loss 0.273, Accuracy 439.8): 100%|█████████████| 477/477 [00:28<00:00, 16.64it/s]
# test_batch (Avg. Loss 0.294, Accuracy 428.6): 100%|████████████████| 53/53 [00:00<00:00, 85.76it/s]
# train_batch (Avg. Loss 0.271, Accuracy 440.6): 100%|█████████████| 477/477 [00:28<00:00, 16.55it/s]
# test_batch (Avg. Loss 0.275, Accuracy 429.9): 100%|████████████████| 53/53 [00:00<00:00, 86.17it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 18
# train_batch (Avg. Loss 0.267, Accuracy 441.2): 100%|█████████████| 477/477 [00:28<00:00, 16.62it/s]
# test_batch (Avg. Loss 0.274, Accuracy 433.1): 100%|████████████████| 53/53 [00:00<00:00, 86.31it/s]
# train_batch (Avg. Loss 0.266, Accuracy 440.5): 100%|█████████████| 477/477 [00:28<00:00, 16.52it/s]
# test_batch (Avg. Loss 0.273, Accuracy 429.3): 100%|████████████████| 53/53 [00:00<00:00, 86.03it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 20
# --- EPOCH 21/200 ---
# train_batch (Avg. Loss 0.266, Accuracy 441.2): 100%|█████████████| 477/477 [00:28<00:00, 16.64it/s]
# test_batch (Avg. Loss 0.275, Accuracy 430.9): 100%|████████████████| 53/53 [00:00<00:00, 87.02it/s]
# train_batch (Avg. Loss 0.265, Accuracy 442.0): 100%|█████████████| 477/477 [00:28<00:00, 16.64it/s]
# test_batch (Avg. Loss 0.268, Accuracy 432.1): 100%|████████████████| 53/53 [00:00<00:00, 86.60it/s]
# train_batch (Avg. Loss 0.264, Accuracy 442.2): 100%|█████████████| 477/477 [00:28<00:00, 16.68it/s]
# test_batch (Avg. Loss 0.271, Accuracy 429.8): 100%|████████████████| 53/53 [00:00<00:00, 84.93it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 23
# train_batch (Avg. Loss 0.264, Accuracy 442.3): 100%|█████████████| 477/477 [00:28<00:00, 16.64it/s]
# test_batch (Avg. Loss 0.270, Accuracy 431.1): 100%|████████████████| 53/53 [00:00<00:00, 85.48it/s]
# train_batch (Avg. Loss 0.263, Accuracy 442.2): 100%|█████████████| 477/477 [00:28<00:00, 16.62it/s]
# test_batch (Avg. Loss 0.269, Accuracy 432.6): 100%|████████████████| 53/53 [00:00<00:00, 85.62it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 25
# train_batch (Avg. Loss 0.263, Accuracy 443.1): 100%|█████████████| 477/477 [00:28<00:00, 16.63it/s]
# test_batch (Avg. Loss 0.267, Accuracy 433.1): 100%|████████████████| 53/53 [00:00<00:00, 84.12it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 26
# train_batch (Avg. Loss 0.262, Accuracy 442.8): 100%|█████████████| 477/477 [00:28<00:00, 16.64it/s]
# test_batch (Avg. Loss 0.267, Accuracy 434.1): 100%|████████████████| 53/53 [00:00<00:00, 86.31it/s]
# train_batch (Avg. Loss 0.260, Accuracy 446.0): 100%|█████████████| 477/477 [00:28<00:00, 16.67it/s]
# test_batch (Avg. Loss 0.265, Accuracy 437.0): 100%|████████████████| 53/53 [00:00<00:00, 85.34it/s]
# train_batch (Avg. Loss 0.260, Accuracy 447.3): 100%|█████████████| 477/477 [00:28<00:00, 16.66it/s]
# test_batch (Avg. Loss 0.263, Accuracy 438.8): 100%|████████████████| 53/53 [00:00<00:00, 85.62it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 29
# train_batch (Avg. Loss 0.260, Accuracy 447.2): 100%|█████████████| 477/477 [00:28<00:00, 16.59it/s]
# test_batch (Avg. Loss 0.264, Accuracy 438.3): 100%|████████████████| 53/53 [00:00<00:00, 85.76it/s]
# --- EPOCH 31/200 ---
# train_batch (Avg. Loss 0.260, Accuracy 447.6): 100%|█████████████| 477/477 [00:28<00:00, 16.63it/s]
# test_batch (Avg. Loss 0.264, Accuracy 438.4): 100%|████████████████| 53/53 [00:00<00:00, 86.17it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 31
# train_batch (Avg. Loss 0.259, Accuracy 448.0): 100%|█████████████| 477/477 [00:28<00:00, 16.59it/s]
# test_batch (Avg. Loss 0.265, Accuracy 436.9): 100%|████████████████| 53/53 [00:00<00:00, 86.46it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 32
# train_batch (Avg. Loss 0.279, Accuracy 448.9): 100%|█████████████| 477/477 [00:28<00:00, 16.62it/s]
# test_batch (Avg. Loss 0.268, Accuracy 437.5): 100%|████████████████| 53/53 [00:00<00:00, 86.46it/s]
# train_batch (Avg. Loss 0.262, Accuracy 448.2): 100%|█████████████| 477/477 [00:28<00:00, 16.59it/s]
# test_batch (Avg. Loss 0.268, Accuracy 436.3): 100%|████████████████| 53/53 [00:00<00:00, 87.60it/s]
# train_batch (Avg. Loss 0.260, Accuracy 448.9): 100%|█████████████| 477/477 [00:28<00:00, 16.65it/s]
# test_batch (Avg. Loss 0.264, Accuracy 438.7): 100%|████████████████| 53/53 [00:00<00:00, 87.02it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 35
# train_batch (Avg. Loss 0.259, Accuracy 448.7): 100%|█████████████| 477/477 [00:28<00:00, 16.62it/s]
# test_batch (Avg. Loss 0.266, Accuracy 437.2): 100%|████████████████| 53/53 [00:00<00:00, 87.45it/s]
# train_batch (Avg. Loss 0.260, Accuracy 449.3): 100%|█████████████| 477/477 [00:28<00:00, 16.69it/s]
# test_batch (Avg. Loss 0.264, Accuracy 438.9): 100%|████████████████| 53/53 [00:00<00:00, 86.17it/s]
# train_batch (Avg. Loss 0.259, Accuracy 449.2): 100%|█████████████| 477/477 [00:28<00:00, 16.64it/s]
# test_batch (Avg. Loss 0.264, Accuracy 438.8): 100%|████████████████| 53/53 [00:00<00:00, 85.20it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 38
# train_batch (Avg. Loss 0.259, Accuracy 449.7): 100%|█████████████| 477/477 [00:28<00:00, 16.67it/s]
# test_batch (Avg. Loss 0.263, Accuracy 439.8): 100%|████████████████| 53/53 [00:00<00:00, 85.89it/s]
# train_batch (Avg. Loss 0.259, Accuracy 449.3): 100%|█████████████| 477/477 [00:28<00:00, 16.64it/s]
# test_batch (Avg. Loss 0.264, Accuracy 439.8): 100%|████████████████| 53/53 [00:00<00:00, 85.48it/s]
# --- EPOCH 41/200 ---
# train_batch (Avg. Loss 0.263, Accuracy 449.5): 100%|█████████████| 477/477 [00:28<00:00, 16.63it/s]
# test_batch (Avg. Loss 0.264, Accuracy 440.0): 100%|████████████████| 53/53 [00:00<00:00, 85.34it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 41
# train_batch (Avg. Loss 0.259, Accuracy 449.7): 100%|█████████████| 477/477 [00:28<00:00, 16.62it/s]
# test_batch (Avg. Loss 0.265, Accuracy 439.5): 100%|████████████████| 53/53 [00:00<00:00, 86.17it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 42
# train_batch (Avg. Loss 0.260, Accuracy 449.9): 100%|█████████████| 477/477 [00:28<00:00, 16.62it/s]
# test_batch (Avg. Loss 0.265, Accuracy 438.8): 100%|████████████████| 53/53 [00:00<00:00, 85.34it/s]
# train_batch (Avg. Loss 0.259, Accuracy 450.2): 100%|█████████████| 477/477 [00:28<00:00, 16.69it/s]
# test_batch (Avg. Loss 0.265, Accuracy 438.3): 100%|████████████████| 53/53 [00:00<00:00, 85.89it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 44
# train_batch (Avg. Loss 0.259, Accuracy 450.4): 100%|█████████████| 477/477 [00:28<00:00, 16.63it/s]
# test_batch (Avg. Loss 0.263, Accuracy 440.8): 100%|████████████████| 53/53 [00:00<00:00, 85.48it/s]
# train_batch (Avg. Loss 0.259, Accuracy 450.4): 100%|█████████████| 477/477 [00:28<00:00, 16.62it/s]
# test_batch (Avg. Loss 0.263, Accuracy 440.3): 100%|████████████████| 53/53 [00:00<00:00, 86.60it/s]
# train_batch (Avg. Loss 0.259, Accuracy 449.8): 100%|█████████████| 477/477 [00:28<00:00, 16.46it/s]
# test_batch (Avg. Loss 0.263, Accuracy 440.5): 100%|████████████████| 53/53 [00:00<00:00, 86.46it/s]
# train_batch (Avg. Loss 0.259, Accuracy 450.8): 100%|█████████████| 477/477 [00:29<00:00, 16.43it/s]
# test_batch (Avg. Loss 0.263, Accuracy 440.7): 100%|████████████████| 53/53 [00:00<00:00, 86.17it/s]
# train_batch (Avg. Loss 0.259, Accuracy 449.7): 100%|█████████████| 477/477 [00:28<00:00, 16.57it/s]
# test_batch (Avg. Loss 0.265, Accuracy 438.8): 100%|████████████████| 53/53 [00:00<00:00, 86.46it/s]
# train_batch (Avg. Loss 0.258, Accuracy 450.9): 100%|█████████████| 477/477 [00:28<00:00, 16.53it/s]
# test_batch (Avg. Loss 0.264, Accuracy 440.3): 100%|████████████████| 53/53 [00:00<00:00, 86.31it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 50
# --- EPOCH 51/200 ---
# train_batch (Avg. Loss 0.259, Accuracy 449.7): 100%|█████████████| 477/477 [00:28<00:00, 16.67it/s]
# test_batch (Avg. Loss 0.264, Accuracy 439.7): 100%|████████████████| 53/53 [00:00<00:00, 85.34it/s]
# train_batch (Avg. Loss 0.258, Accuracy 450.9): 100%|█████████████| 477/477 [00:28<00:00, 16.69it/s]
# test_batch (Avg. Loss 0.264, Accuracy 440.3): 100%|████████████████| 53/53 [00:00<00:00, 85.20it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 52
# train_batch (Avg. Loss 0.258, Accuracy 451.1): 100%|█████████████| 477/477 [00:28<00:00, 16.63it/s]
# test_batch (Avg. Loss 0.264, Accuracy 439.7): 100%|████████████████| 53/53 [00:00<00:00, 84.93it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 53
# train_batch (Avg. Loss 0.258, Accuracy 451.3): 100%|█████████████| 477/477 [00:28<00:00, 16.61it/s]
# test_batch (Avg. Loss 0.264, Accuracy 439.7): 100%|████████████████| 53/53 [00:00<00:00, 85.20it/s]
# train_batch (Avg. Loss 0.273, Accuracy 450.8): 100%|█████████████| 477/477 [00:28<00:00, 16.67it/s]
# test_batch (Avg. Loss 0.318, Accuracy 439.9): 100%|████████████████| 53/53 [00:00<00:00, 84.52it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 55
# train_batch (Avg. Loss 0.262, Accuracy 451.3): 100%|█████████████| 477/477 [00:28<00:00, 16.70it/s]
# test_batch (Avg. Loss 0.264, Accuracy 440.1): 100%|████████████████| 53/53 [00:00<00:00, 85.20it/s]
# train_batch (Avg. Loss 0.259, Accuracy 451.5): 100%|█████████████| 477/477 [00:28<00:00, 16.65it/s]
# test_batch (Avg. Loss 0.264, Accuracy 439.6): 100%|████████████████| 53/53 [00:00<00:00, 85.89it/s]
# train_batch (Avg. Loss 0.258, Accuracy 451.9): 100%|█████████████| 477/477 [00:28<00:00, 16.66it/s]
# test_batch (Avg. Loss 0.263, Accuracy 441.6): 100%|████████████████| 53/53 [00:00<00:00, 85.89it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 58
# train_batch (Avg. Loss 0.258, Accuracy 452.3): 100%|█████████████| 477/477 [00:28<00:00, 16.65it/s]
# test_batch (Avg. Loss 0.263, Accuracy 441.8): 100%|████████████████| 53/53 [00:00<00:00, 85.48it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 59
# train_batch (Avg. Loss 0.258, Accuracy 451.9): 100%|█████████████| 477/477 [00:28<00:00, 16.63it/s]
# test_batch (Avg. Loss 0.264, Accuracy 440.0): 100%|████████████████| 53/53 [00:00<00:00, 85.34it/s]
# --- EPOCH 61/200 ---
# train_batch (Avg. Loss 0.258, Accuracy 452.1): 100%|█████████████| 477/477 [00:28<00:00, 16.56it/s]
# test_batch (Avg. Loss 0.263, Accuracy 441.4): 100%|████████████████| 53/53 [00:00<00:00, 85.62it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 61
# train_batch (Avg. Loss 0.258, Accuracy 452.3): 100%|█████████████| 477/477 [00:28<00:00, 16.65it/s]
# test_batch (Avg. Loss 0.264, Accuracy 441.2): 100%|████████████████| 53/53 [00:00<00:00, 86.46it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 62
# train_batch (Avg. Loss 0.258, Accuracy 453.2): 100%|█████████████| 477/477 [00:28<00:00, 16.64it/s]
# test_batch (Avg. Loss 0.262, Accuracy 442.4): 100%|████████████████| 53/53 [00:00<00:00, 86.88it/s]
# train_batch (Avg. Loss 0.258, Accuracy 452.5): 100%|█████████████| 477/477 [00:28<00:00, 16.73it/s]
# test_batch (Avg. Loss 0.263, Accuracy 442.8): 100%|████████████████| 53/53 [00:00<00:00, 86.74it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 64
# train_batch (Avg. Loss 0.257, Accuracy 453.3): 100%|█████████████| 477/477 [00:28<00:00, 16.65it/s]
# test_batch (Avg. Loss 0.263, Accuracy 442.3): 100%|████████████████| 53/53 [00:00<00:00, 86.17it/s]
# train_batch (Avg. Loss 0.257, Accuracy 454.1): 100%|█████████████| 477/477 [00:28<00:00, 16.68it/s]
# test_batch (Avg. Loss 0.264, Accuracy 441.2): 100%|████████████████| 53/53 [00:00<00:00, 86.46it/s]
# train_batch (Avg. Loss 0.257, Accuracy 454.3): 100%|█████████████| 477/477 [00:28<00:00, 16.67it/s]
# test_batch (Avg. Loss 0.264, Accuracy 439.9): 100%|████████████████| 53/53 [00:00<00:00, 85.89it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 67
# train_batch (Avg. Loss 0.257, Accuracy 454.1): 100%|█████████████| 477/477 [00:28<00:00, 16.67it/s]
# test_batch (Avg. Loss 0.264, Accuracy 441.7): 100%|████████████████| 53/53 [00:00<00:00, 85.76it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 68
# train_batch (Avg. Loss 0.257, Accuracy 454.5): 100%|█████████████| 477/477 [00:28<00:00, 16.63it/s]
# test_batch (Avg. Loss 0.263, Accuracy 443.7): 100%|████████████████| 53/53 [00:00<00:00, 85.48it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 69
# train_batch (Avg. Loss 0.259, Accuracy 455.0): 100%|█████████████| 477/477 [00:28<00:00, 16.61it/s]
# test_batch (Avg. Loss 0.262, Accuracy 445.1): 100%|████████████████| 53/53 [00:00<00:00, 85.07it/s]
# --- EPOCH 71/200 ---
# train_batch (Avg. Loss 0.257, Accuracy 455.3): 100%|█████████████| 477/477 [00:28<00:00, 16.66it/s]
# test_batch (Avg. Loss 0.262, Accuracy 444.4): 100%|████████████████| 53/53 [00:00<00:00, 85.48it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 71
# train_batch (Avg. Loss 0.257, Accuracy 455.1): 100%|█████████████| 477/477 [00:28<00:00, 16.66it/s]
# test_batch (Avg. Loss 0.263, Accuracy 443.7): 100%|████████████████| 53/53 [00:00<00:00, 84.93it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 72
# train_batch (Avg. Loss 0.257, Accuracy 455.2): 100%|█████████████| 477/477 [00:28<00:00, 16.58it/s]
# test_batch (Avg. Loss 0.261, Accuracy 444.7): 100%|████████████████| 53/53 [00:00<00:00, 86.74it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 73
# train_batch (Avg. Loss 0.256, Accuracy 455.7): 100%|█████████████| 477/477 [00:28<00:00, 16.59it/s]
# test_batch (Avg. Loss 0.261, Accuracy 444.6): 100%|████████████████| 53/53 [00:00<00:00, 86.88it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 74
# train_batch (Avg. Loss 0.257, Accuracy 455.2): 100%|█████████████| 477/477 [00:28<00:00, 16.63it/s]
# test_batch (Avg. Loss 0.262, Accuracy 444.7): 100%|████████████████| 53/53 [00:00<00:00, 87.17it/s]
# train_batch (Avg. Loss 0.258, Accuracy 454.8): 100%|█████████████| 477/477 [00:28<00:00, 16.60it/s]
# test_batch (Avg. Loss 0.264, Accuracy 443.1): 100%|████████████████| 53/53 [00:00<00:00, 87.31it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 76
# train_batch (Avg. Loss 0.257, Accuracy 455.8): 100%|█████████████| 477/477 [00:28<00:00, 16.65it/s]
# test_batch (Avg. Loss 0.263, Accuracy 443.4): 100%|████████████████| 53/53 [00:00<00:00, 84.66it/s]
# train_batch (Avg. Loss 0.256, Accuracy 456.0): 100%|█████████████| 477/477 [00:28<00:00, 16.67it/s]
# test_batch (Avg. Loss 0.264, Accuracy 441.9): 100%|████████████████| 53/53 [00:00<00:00, 84.39it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 78
# train_batch (Avg. Loss 0.256, Accuracy 456.5): 100%|█████████████| 477/477 [00:28<00:00, 16.63it/s]
# test_batch (Avg. Loss 0.262, Accuracy 444.7): 100%|████████████████| 53/53 [00:00<00:00, 85.76it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 79
# train_batch (Avg. Loss 0.256, Accuracy 456.4): 100%|█████████████| 477/477 [00:28<00:00, 16.66it/s]
# test_batch (Avg. Loss 0.262, Accuracy 444.7): 100%|████████████████| 53/53 [00:00<00:00, 85.76it/s]
# --- EPOCH 81/200 ---
# train_batch (Avg. Loss 0.256, Accuracy 455.3): 100%|█████████████| 477/477 [00:28<00:00, 16.67it/s]
# test_batch (Avg. Loss 0.264, Accuracy 443.0): 100%|████████████████| 53/53 [00:00<00:00, 86.60it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 81
# train_batch (Avg. Loss 0.256, Accuracy 456.5): 100%|█████████████| 477/477 [00:28<00:00, 16.61it/s]
# test_batch (Avg. Loss 0.262, Accuracy 444.7): 100%|████████████████| 53/53 [00:00<00:00, 85.76it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 82
# train_batch (Avg. Loss 0.256, Accuracy 456.9): 100%|█████████████| 477/477 [00:28<00:00, 16.63it/s]
# test_batch (Avg. Loss 0.261, Accuracy 445.8): 100%|████████████████| 53/53 [00:00<00:00, 85.76it/s]
# train_batch (Avg. Loss 0.256, Accuracy 455.9): 100%|█████████████| 477/477 [00:28<00:00, 16.63it/s]
# test_batch (Avg. Loss 0.262, Accuracy 444.5): 100%|████████████████| 53/53 [00:00<00:00, 85.20it/s]
# train_batch (Avg. Loss 0.266, Accuracy 456.7): 100%|█████████████| 477/477 [00:28<00:00, 16.70it/s]
# test_batch (Avg. Loss 0.279, Accuracy 444.4): 100%|████████████████| 53/53 [00:00<00:00, 85.07it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 85
# train_batch (Avg. Loss 0.258, Accuracy 456.5): 100%|█████████████| 477/477 [00:28<00:00, 16.60it/s]
# test_batch (Avg. Loss 0.262, Accuracy 445.1): 100%|████████████████| 53/53 [00:00<00:00, 85.34it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 86
# train_batch (Avg. Loss 0.256, Accuracy 456.9): 100%|█████████████| 477/477 [00:28<00:00, 16.63it/s]
# test_batch (Avg. Loss 0.261, Accuracy 446.6): 100%|████████████████| 53/53 [00:00<00:00, 85.76it/s]
# train_batch (Avg. Loss 0.256, Accuracy 456.8): 100%|█████████████| 477/477 [00:28<00:00, 16.56it/s]
# test_batch (Avg. Loss 0.262, Accuracy 445.8): 100%|████████████████| 53/53 [00:00<00:00, 87.60it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 88
# train_batch (Avg. Loss 0.256, Accuracy 456.9): 100%|█████████████| 477/477 [00:28<00:00, 16.57it/s]
# test_batch (Avg. Loss 0.261, Accuracy 446.6): 100%|████████████████| 53/53 [00:00<00:00, 79.69it/s]
# train_batch (Avg. Loss 0.256, Accuracy 457.0): 100%|█████████████| 477/477 [00:29<00:00, 16.31it/s]
# test_batch (Avg. Loss 0.261, Accuracy 446.1): 100%|████████████████| 53/53 [00:00<00:00, 86.74it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 90
# --- EPOCH 91/200 ---
# train_batch (Avg. Loss 0.256, Accuracy 456.6): 100%|█████████████| 477/477 [00:28<00:00, 16.66it/s]
# test_batch (Avg. Loss 0.261, Accuracy 446.0): 100%|████████████████| 53/53 [00:00<00:00, 85.62it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 91
# train_batch (Avg. Loss 0.256, Accuracy 456.5): 100%|█████████████| 477/477 [00:28<00:00, 16.67it/s]
# test_batch (Avg. Loss 0.263, Accuracy 444.0): 100%|████████████████| 53/53 [00:00<00:00, 85.76it/s]
# train_batch (Avg. Loss 0.256, Accuracy 456.3): 100%|█████████████| 477/477 [00:28<00:00, 16.67it/s]
# test_batch (Avg. Loss 0.262, Accuracy 444.4): 100%|████████████████| 53/53 [00:00<00:00, 86.88it/s]
# train_batch (Avg. Loss 0.256, Accuracy 456.8): 100%|█████████████| 477/477 [00:28<00:00, 16.67it/s]
# test_batch (Avg. Loss 0.263, Accuracy 443.5): 100%|████████████████| 53/53 [00:00<00:00, 86.31it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 94
# train_batch (Avg. Loss 0.256, Accuracy 457.1): 100%|█████████████| 477/477 [00:28<00:00, 16.74it/s]
# test_batch (Avg. Loss 0.262, Accuracy 444.3): 100%|████████████████| 53/53 [00:00<00:00, 85.07it/s]
# train_batch (Avg. Loss 0.256, Accuracy 457.7): 100%|█████████████| 477/477 [00:28<00:00, 16.69it/s]
# test_batch (Avg. Loss 0.261, Accuracy 446.0): 100%|████████████████| 53/53 [00:00<00:00, 85.20it/s]
# train_batch (Avg. Loss 0.256, Accuracy 457.3): 100%|█████████████| 477/477 [00:28<00:00, 16.70it/s]
# test_batch (Avg. Loss 0.262, Accuracy 446.2): 100%|████████████████| 53/53 [00:00<00:00, 85.20it/s]
# train_batch (Avg. Loss 0.256, Accuracy 457.4): 100%|█████████████| 477/477 [00:28<00:00, 16.68it/s]
# test_batch (Avg. Loss 0.262, Accuracy 445.1): 100%|████████████████| 53/53 [00:00<00:00, 86.88it/s]
# train_batch (Avg. Loss 0.256, Accuracy 456.8): 100%|█████████████| 477/477 [00:28<00:00, 16.72it/s]
# test_batch (Avg. Loss 0.262, Accuracy 445.7): 100%|████████████████| 53/53 [00:00<00:00, 78.05it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 99
# train_batch (Avg. Loss 0.256, Accuracy 457.2): 100%|█████████████| 477/477 [00:28<00:00, 16.70it/s]
# test_batch (Avg. Loss 0.262, Accuracy 445.0): 100%|████████████████| 53/53 [00:00<00:00, 81.28it/s]
# --- EPOCH 101/200 ---
# train_batch (Avg. Loss 0.256, Accuracy 457.5): 100%|█████████████| 477/477 [00:28<00:00, 16.63it/s]
# test_batch (Avg. Loss 0.261, Accuracy 446.0): 100%|████████████████| 53/53 [00:00<00:00, 86.17it/s]
# train_batch (Avg. Loss 0.256, Accuracy 457.9): 100%|█████████████| 477/477 [00:28<00:00, 16.63it/s]
# test_batch (Avg. Loss 0.260, Accuracy 447.3): 100%|████████████████| 53/53 [00:00<00:00, 87.60it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 102
# train_batch (Avg. Loss 0.256, Accuracy 456.6): 100%|█████████████| 477/477 [00:28<00:00, 16.74it/s]
# test_batch (Avg. Loss 0.261, Accuracy 446.2): 100%|████████████████| 53/53 [00:00<00:00, 84.80it/s]
# train_batch (Avg. Loss 0.256, Accuracy 457.5): 100%|█████████████| 477/477 [00:28<00:00, 16.60it/s]
# test_batch (Avg. Loss 0.261, Accuracy 446.2): 100%|████████████████| 53/53 [00:00<00:00, 85.89it/s]
# train_batch (Avg. Loss 0.256, Accuracy 457.3): 100%|█████████████| 477/477 [00:28<00:00, 16.75it/s]
# test_batch (Avg. Loss 0.261, Accuracy 446.7): 100%|████████████████| 53/53 [00:00<00:00, 82.29it/s]
# train_batch (Avg. Loss 0.256, Accuracy 457.5): 100%|█████████████| 477/477 [00:28<00:00, 16.72it/s]
# test_batch (Avg. Loss 0.261, Accuracy 446.0): 100%|████████████████| 53/53 [00:00<00:00, 86.17it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 106
# train_batch (Avg. Loss 0.255, Accuracy 457.5): 100%|█████████████| 477/477 [00:28<00:00, 16.70it/s]
# test_batch (Avg. Loss 0.261, Accuracy 446.2): 100%|████████████████| 53/53 [00:00<00:00, 86.03it/s]
# train_batch (Avg. Loss 0.255, Accuracy 458.3): 100%|█████████████| 477/477 [00:28<00:00, 16.72it/s]
# test_batch (Avg. Loss 0.262, Accuracy 444.9): 100%|████████████████| 53/53 [00:00<00:00, 86.17it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 108
# train_batch (Avg. Loss 0.257, Accuracy 458.3): 100%|█████████████| 477/477 [00:28<00:00, 16.70it/s]
# test_batch (Avg. Loss 0.271, Accuracy 445.8): 100%|████████████████| 53/53 [00:00<00:00, 84.39it/s]
# train_batch (Avg. Loss 0.256, Accuracy 458.4): 100%|█████████████| 477/477 [00:29<00:00, 16.25it/s]
# test_batch (Avg. Loss 0.261, Accuracy 447.9): 100%|████████████████| 53/53 [00:00<00:00, 81.79it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 110
# --- EPOCH 111/200 ---
# train_batch (Avg. Loss 0.255, Accuracy 459.1): 100%|█████████████| 477/477 [00:30<00:00, 15.90it/s]
# test_batch (Avg. Loss 0.260, Accuracy 448.6): 100%|████████████████| 53/53 [00:00<00:00, 86.74it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 111
# train_batch (Avg. Loss 0.255, Accuracy 458.9): 100%|█████████████| 477/477 [00:29<00:00, 15.97it/s]
# test_batch (Avg. Loss 0.261, Accuracy 447.7): 100%|████████████████| 53/53 [00:00<00:00, 84.52it/s]
# train_batch (Avg. Loss 0.255, Accuracy 459.6): 100%|█████████████| 477/477 [00:29<00:00, 16.23it/s]
# test_batch (Avg. Loss 0.260, Accuracy 448.9): 100%|████████████████| 53/53 [00:00<00:00, 84.66it/s]
# train_batch (Avg. Loss 0.254, Accuracy 460.2): 100%|█████████████| 477/477 [00:29<00:00, 16.35it/s]
# test_batch (Avg. Loss 0.260, Accuracy 449.4): 100%|████████████████| 53/53 [00:00<00:00, 84.66it/s]
# train_batch (Avg. Loss 0.255, Accuracy 460.5): 100%|█████████████| 477/477 [00:28<00:00, 16.57it/s]
# test_batch (Avg. Loss 0.259, Accuracy 449.7): 100%|████████████████| 53/53 [00:00<00:00, 83.59it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 115
# train_batch (Avg. Loss 0.254, Accuracy 460.5): 100%|█████████████| 477/477 [00:29<00:00, 16.38it/s]
# test_batch (Avg. Loss 0.259, Accuracy 450.5): 100%|████████████████| 53/53 [00:00<00:00, 83.33it/s]
# train_batch (Avg. Loss 0.254, Accuracy 460.4): 100%|█████████████| 477/477 [00:29<00:00, 16.45it/s]
# test_batch (Avg. Loss 0.260, Accuracy 449.7): 100%|████████████████| 53/53 [00:00<00:00, 82.55it/s]
# train_batch (Avg. Loss 0.254, Accuracy 460.3): 100%|█████████████| 477/477 [00:29<00:00, 16.40it/s]
# test_batch (Avg. Loss 0.260, Accuracy 449.4): 100%|████████████████| 53/53 [00:00<00:00, 82.94it/s]
# train_batch (Avg. Loss 0.254, Accuracy 461.2): 100%|█████████████| 477/477 [00:29<00:00, 16.33it/s]
# test_batch (Avg. Loss 0.260, Accuracy 449.8): 100%|████████████████| 53/53 [00:00<00:00, 83.33it/s]
# train_batch (Avg. Loss 0.254, Accuracy 461.1): 100%|█████████████| 477/477 [00:29<00:00, 16.24it/s]
# test_batch (Avg. Loss 0.260, Accuracy 450.6): 100%|████████████████| 53/53 [00:00<00:00, 86.60it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 120
# --- EPOCH 121/200 ---
# train_batch (Avg. Loss 0.254, Accuracy 461.4): 100%|█████████████| 477/477 [00:28<00:00, 16.59it/s]
# test_batch (Avg. Loss 0.259, Accuracy 450.7): 100%|████████████████| 53/53 [00:00<00:00, 84.52it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 121
# train_batch (Avg. Loss 0.254, Accuracy 461.3): 100%|█████████████| 477/477 [00:30<00:00, 15.76it/s]
# test_batch (Avg. Loss 0.260, Accuracy 449.9): 100%|████████████████| 53/53 [00:00<00:00, 88.18it/s]
# train_batch (Avg. Loss 0.254, Accuracy 461.4): 100%|█████████████| 477/477 [00:29<00:00, 16.42it/s]
# test_batch (Avg. Loss 0.260, Accuracy 450.2): 100%|████████████████| 53/53 [00:00<00:00, 83.07it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 123
# train_batch (Avg. Loss 0.254, Accuracy 462.0): 100%|█████████████| 477/477 [00:29<00:00, 16.44it/s]
# test_batch (Avg. Loss 0.259, Accuracy 451.5): 100%|████████████████| 53/53 [00:00<00:00, 88.33it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 124
# train_batch (Avg. Loss 0.254, Accuracy 461.3): 100%|█████████████| 477/477 [00:28<00:00, 16.76it/s]
# test_batch (Avg. Loss 0.260, Accuracy 450.2): 100%|████████████████| 53/53 [00:00<00:00, 88.18it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 125
# train_batch (Avg. Loss 0.254, Accuracy 462.0): 100%|█████████████| 477/477 [00:28<00:00, 16.92it/s]
# test_batch (Avg. Loss 0.259, Accuracy 451.2): 100%|████████████████| 53/53 [00:00<00:00, 88.18it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 126
# train_batch (Avg. Loss 0.254, Accuracy 462.0): 100%|█████████████| 477/477 [00:28<00:00, 16.93it/s]
# test_batch (Avg. Loss 0.259, Accuracy 450.8): 100%|████████████████| 53/53 [00:00<00:00, 90.13it/s]
# train_batch (Avg. Loss 0.254, Accuracy 462.1): 100%|█████████████| 477/477 [00:28<00:00, 16.79it/s]
# test_batch (Avg. Loss 0.259, Accuracy 451.5): 100%|████████████████| 53/53 [00:00<00:00, 86.03it/s]
# train_batch (Avg. Loss 0.254, Accuracy 461.6): 100%|█████████████| 477/477 [00:29<00:00, 16.19it/s]
# test_batch (Avg. Loss 0.263, Accuracy 449.6): 100%|████████████████| 53/53 [00:00<00:00, 85.20it/s]
# train_batch (Avg. Loss 0.260, Accuracy 462.3): 100%|█████████████| 477/477 [00:30<00:00, 15.65it/s]
# test_batch (Avg. Loss 0.260, Accuracy 450.6): 100%|████████████████| 53/53 [00:00<00:00, 76.36it/s]
# --- EPOCH 131/200 ---
# train_batch (Avg. Loss 0.255, Accuracy 461.9): 100%|█████████████| 477/477 [00:29<00:00, 16.18it/s]
# test_batch (Avg. Loss 0.262, Accuracy 450.9): 100%|████████████████| 53/53 [00:00<00:00, 84.93it/s]
# train_batch (Avg. Loss 0.254, Accuracy 462.3): 100%|█████████████| 477/477 [00:28<00:00, 16.63it/s]
# test_batch (Avg. Loss 0.260, Accuracy 450.2): 100%|████████████████| 53/53 [00:00<00:00, 84.66it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 132
# train_batch (Avg. Loss 0.254, Accuracy 462.2): 100%|█████████████| 477/477 [00:28<00:00, 16.62it/s]
# test_batch (Avg. Loss 0.259, Accuracy 450.8): 100%|████████████████| 53/53 [00:00<00:00, 84.26it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 133
# train_batch (Avg. Loss 0.254, Accuracy 462.6): 100%|█████████████| 477/477 [00:28<00:00, 16.57it/s]
# test_batch (Avg. Loss 0.259, Accuracy 451.9): 100%|████████████████| 53/53 [00:00<00:00, 84.93it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 134
# train_batch (Avg. Loss 0.254, Accuracy 461.9): 100%|█████████████| 477/477 [00:29<00:00, 16.07it/s]
# test_batch (Avg. Loss 0.260, Accuracy 450.5): 100%|████████████████| 53/53 [00:00<00:00, 64.32it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 135
# train_batch (Avg. Loss 0.254, Accuracy 461.9): 100%|█████████████| 477/477 [00:31<00:00, 15.38it/s]
# test_batch (Avg. Loss 0.259, Accuracy 451.1): 100%|████████████████| 53/53 [00:00<00:00, 83.07it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 136
# train_batch (Avg. Loss 0.254, Accuracy 461.8): 100%|█████████████| 477/477 [00:28<00:00, 16.46it/s]
# test_batch (Avg. Loss 0.260, Accuracy 450.3): 100%|████████████████| 53/53 [00:00<00:00, 84.12it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 137
# train_batch (Avg. Loss 0.254, Accuracy 461.5): 100%|█████████████| 477/477 [00:31<00:00, 14.96it/s]
# test_batch (Avg. Loss 0.260, Accuracy 449.8): 100%|████████████████| 53/53 [00:00<00:00, 85.48it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 138
# train_batch (Avg. Loss 0.254, Accuracy 462.3): 100%|█████████████| 477/477 [00:28<00:00, 16.54it/s]
# test_batch (Avg. Loss 0.260, Accuracy 450.8): 100%|████████████████| 53/53 [00:00<00:00, 85.34it/s]
# train_batch (Avg. Loss 0.254, Accuracy 462.4): 100%|█████████████| 477/477 [00:28<00:00, 16.52it/s]
# test_batch (Avg. Loss 0.260, Accuracy 450.7): 100%|████████████████| 53/53 [00:00<00:00, 84.52it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 140
# --- EPOCH 141/200 ---
# train_batch (Avg. Loss 0.254, Accuracy 462.5): 100%|█████████████| 477/477 [00:28<00:00, 16.54it/s]
# test_batch (Avg. Loss 0.260, Accuracy 450.4): 100%|████████████████| 53/53 [00:00<00:00, 84.93it/s]
# train_batch (Avg. Loss 0.254, Accuracy 461.8): 100%|█████████████| 477/477 [00:28<00:00, 16.73it/s]
# test_batch (Avg. Loss 0.260, Accuracy 450.7): 100%|████████████████| 53/53 [00:00<00:00, 84.66it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 142
# train_batch (Avg. Loss 0.254, Accuracy 461.8): 100%|█████████████| 477/477 [00:28<00:00, 16.57it/s]
# test_batch (Avg. Loss 0.261, Accuracy 449.3): 100%|████████████████| 53/53 [00:00<00:00, 85.07it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 143
# train_batch (Avg. Loss 0.254, Accuracy 462.5): 100%|█████████████| 477/477 [00:28<00:00, 16.72it/s]
# test_batch (Avg. Loss 0.259, Accuracy 452.1): 100%|████████████████| 53/53 [00:00<00:00, 85.76it/s]
# train_batch (Avg. Loss 0.254, Accuracy 462.0): 100%|█████████████| 477/477 [00:28<00:00, 16.67it/s]
# test_batch (Avg. Loss 0.260, Accuracy 450.6): 100%|████████████████| 53/53 [00:00<00:00, 86.31it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 145
# train_batch (Avg. Loss 0.254, Accuracy 462.4): 100%|█████████████| 477/477 [00:28<00:00, 16.60it/s]
# test_batch (Avg. Loss 0.260, Accuracy 451.1): 100%|████████████████| 53/53 [00:00<00:00, 85.76it/s]
# train_batch (Avg. Loss 0.254, Accuracy 461.7): 100%|█████████████| 477/477 [00:28<00:00, 16.68it/s]
# test_batch (Avg. Loss 0.259, Accuracy 451.3): 100%|████████████████| 53/53 [00:00<00:00, 85.07it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 147
# train_batch (Avg. Loss 0.254, Accuracy 462.4): 100%|█████████████| 477/477 [00:28<00:00, 16.59it/s]
# test_batch (Avg. Loss 0.259, Accuracy 451.7): 100%|████████████████| 53/53 [00:00<00:00, 86.46it/s]
# train_batch (Avg. Loss 0.254, Accuracy 462.2): 100%|█████████████| 477/477 [00:28<00:00, 16.64it/s]
# test_batch (Avg. Loss 0.259, Accuracy 451.3): 100%|████████████████| 53/53 [00:00<00:00, 82.94it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 149
# train_batch (Avg. Loss 0.254, Accuracy 462.7): 100%|█████████████| 477/477 [00:28<00:00, 16.66it/s]
# test_batch (Avg. Loss 0.259, Accuracy 451.8): 100%|████████████████| 53/53 [00:00<00:00, 86.31it/s]
# --- EPOCH 151/200 ---
# train_batch (Avg. Loss 0.254, Accuracy 462.0): 100%|█████████████| 477/477 [00:28<00:00, 16.60it/s]
# test_batch (Avg. Loss 0.259, Accuracy 451.1): 100%|████████████████| 53/53 [00:00<00:00, 85.48it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 151
# train_batch (Avg. Loss 0.254, Accuracy 462.1): 100%|█████████████| 477/477 [00:28<00:00, 16.67it/s]
# test_batch (Avg. Loss 0.260, Accuracy 450.6): 100%|████████████████| 53/53 [00:00<00:00, 85.89it/s]
# train_batch (Avg. Loss 0.257, Accuracy 462.3): 100%|█████████████| 477/477 [00:28<00:00, 16.72it/s]
# test_batch (Avg. Loss 0.260, Accuracy 450.5): 100%|████████████████| 53/53 [00:00<00:00, 85.07it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 153
# train_batch (Avg. Loss 0.257, Accuracy 462.4): 100%|█████████████| 477/477 [00:28<00:00, 16.67it/s]
# test_batch (Avg. Loss 0.260, Accuracy 450.7): 100%|████████████████| 53/53 [00:00<00:00, 85.76it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 154
# train_batch (Avg. Loss 0.254, Accuracy 461.8): 100%|█████████████| 477/477 [00:28<00:00, 16.61it/s]
# test_batch (Avg. Loss 0.260, Accuracy 450.0): 100%|████████████████| 53/53 [00:00<00:00, 85.89it/s]
# train_batch (Avg. Loss 0.254, Accuracy 462.6): 100%|█████████████| 477/477 [00:28<00:00, 16.66it/s]
# test_batch (Avg. Loss 0.259, Accuracy 451.9): 100%|████████████████| 53/53 [00:00<00:00, 86.17it/s]
# train_batch (Avg. Loss 0.254, Accuracy 462.4): 100%|█████████████| 477/477 [00:28<00:00, 16.66it/s]
# test_batch (Avg. Loss 0.259, Accuracy 451.5): 100%|████████████████| 53/53 [00:00<00:00, 86.31it/s]
# train_batch (Avg. Loss 0.254, Accuracy 462.3): 100%|█████████████| 477/477 [00:28<00:00, 16.67it/s]
# test_batch (Avg. Loss 0.259, Accuracy 451.4): 100%|████████████████| 53/53 [00:00<00:00, 87.45it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 158
# train_batch (Avg. Loss 0.254, Accuracy 462.2): 100%|█████████████| 477/477 [00:28<00:00, 16.60it/s]
# test_batch (Avg. Loss 0.260, Accuracy 451.0): 100%|████████████████| 53/53 [00:00<00:00, 86.60it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 159
# train_batch (Avg. Loss 0.254, Accuracy 462.5): 100%|█████████████| 477/477 [00:28<00:00, 16.59it/s]
# test_batch (Avg. Loss 0.260, Accuracy 451.0): 100%|████████████████| 53/53 [00:00<00:00, 85.76it/s]
# --- EPOCH 161/200 ---
# train_batch (Avg. Loss 0.254, Accuracy 462.3): 100%|█████████████| 477/477 [00:28<00:00, 16.63it/s]
# test_batch (Avg. Loss 0.260, Accuracy 449.5): 100%|████████████████| 53/53 [00:00<00:00, 86.17it/s]
# train_batch (Avg. Loss 0.254, Accuracy 462.5): 100%|█████████████| 477/477 [00:28<00:00, 16.63it/s]
# test_batch (Avg. Loss 0.259, Accuracy 451.3): 100%|████████████████| 53/53 [00:00<00:00, 86.74it/s]
# train_batch (Avg. Loss 0.254, Accuracy 462.4): 100%|█████████████| 477/477 [00:28<00:00, 16.66it/s]
# test_batch (Avg. Loss 0.259, Accuracy 450.2): 100%|████████████████| 53/53 [00:00<00:00, 84.39it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 163
# train_batch (Avg. Loss 0.254, Accuracy 462.7): 100%|█████████████| 477/477 [00:28<00:00, 16.68it/s]
# test_batch (Avg. Loss 0.259, Accuracy 451.0): 100%|████████████████| 53/53 [00:00<00:00, 85.89it/s]
# train_batch (Avg. Loss 0.254, Accuracy 462.7): 100%|█████████████| 477/477 [00:28<00:00, 16.64it/s]
# test_batch (Avg. Loss 0.259, Accuracy 451.2): 100%|████████████████| 53/53 [00:00<00:00, 84.66it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 165
# train_batch (Avg. Loss 0.254, Accuracy 462.8): 100%|█████████████| 477/477 [00:28<00:00, 16.72it/s]
# test_batch (Avg. Loss 0.260, Accuracy 450.9): 100%|████████████████| 53/53 [00:00<00:00, 85.48it/s]
# train_batch (Avg. Loss 0.253, Accuracy 462.7): 100%|█████████████| 477/477 [00:28<00:00, 16.70it/s]
# test_batch (Avg. Loss 0.260, Accuracy 450.2): 100%|████████████████| 53/53 [00:00<00:00, 85.48it/s]
# train_batch (Avg. Loss 0.254, Accuracy 463.2): 100%|█████████████| 477/477 [00:28<00:00, 16.71it/s]
# test_batch (Avg. Loss 0.260, Accuracy 451.1): 100%|████████████████| 53/53 [00:00<00:00, 85.89it/s]
# train_batch (Avg. Loss 0.254, Accuracy 462.4): 100%|█████████████| 477/477 [00:28<00:00, 16.67it/s]
# test_batch (Avg. Loss 0.260, Accuracy 450.4): 100%|████████████████| 53/53 [00:00<00:00, 86.17it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 169
# train_batch (Avg. Loss 0.254, Accuracy 463.0): 100%|█████████████| 477/477 [00:28<00:00, 16.70it/s]
# test_batch (Avg. Loss 0.259, Accuracy 451.9): 100%|████████████████| 53/53 [00:00<00:00, 84.39it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 170
# --- EPOCH 171/200 ---
# train_batch (Avg. Loss 0.254, Accuracy 463.0): 100%|█████████████| 477/477 [00:28<00:00, 16.62it/s]
# test_batch (Avg. Loss 0.260, Accuracy 451.2): 100%|████████████████| 53/53 [00:00<00:00, 86.88it/s]
# train_batch (Avg. Loss 0.254, Accuracy 463.4): 100%|█████████████| 477/477 [00:28<00:00, 16.65it/s]
# test_batch (Avg. Loss 0.259, Accuracy 451.7): 100%|████████████████| 53/53 [00:00<00:00, 86.03it/s]
# train_batch (Avg. Loss 0.254, Accuracy 462.7): 100%|█████████████| 477/477 [00:28<00:00, 16.68it/s]
# test_batch (Avg. Loss 0.259, Accuracy 451.3): 100%|████████████████| 53/53 [00:00<00:00, 85.20it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 173
# train_batch (Avg. Loss 0.254, Accuracy 462.9): 100%|█████████████| 477/477 [00:28<00:00, 16.69it/s]
# test_batch (Avg. Loss 0.260, Accuracy 450.9): 100%|████████████████| 53/53 [00:00<00:00, 86.88it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 174
# train_batch (Avg. Loss 0.255, Accuracy 463.3): 100%|█████████████| 477/477 [00:29<00:00, 16.39it/s]
# test_batch (Avg. Loss 0.260, Accuracy 451.2): 100%|████████████████| 53/53 [00:00<00:00, 82.17it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 175
# train_batch (Avg. Loss 0.254, Accuracy 463.2): 100%|█████████████| 477/477 [00:29<00:00, 16.39it/s]
# test_batch (Avg. Loss 0.259, Accuracy 451.3): 100%|████████████████| 53/53 [00:00<00:00, 77.37it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 176
# train_batch (Avg. Loss 0.254, Accuracy 462.9): 100%|█████████████| 477/477 [00:30<00:00, 15.88it/s]
# test_batch (Avg. Loss 0.260, Accuracy 451.0): 100%|████████████████| 53/53 [00:00<00:00, 83.99it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 177
# train_batch (Avg. Loss 0.254, Accuracy 462.8): 100%|█████████████| 477/477 [00:28<00:00, 16.45it/s]
# test_batch (Avg. Loss 0.260, Accuracy 451.2): 100%|████████████████| 53/53 [00:00<00:00, 81.53it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 178
# train_batch (Avg. Loss 0.253, Accuracy 463.4): 100%|█████████████| 477/477 [00:29<00:00, 16.40it/s]
# test_batch (Avg. Loss 0.258, Accuracy 452.3): 100%|████████████████| 53/53 [00:00<00:00, 83.72it/s]
# train_batch (Avg. Loss 0.254, Accuracy 463.1): 100%|█████████████| 477/477 [00:29<00:00, 16.07it/s]
# test_batch (Avg. Loss 0.259, Accuracy 452.2): 100%|████████████████| 53/53 [00:00<00:00, 84.66it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 180
# --- EPOCH 181/200 ---
# train_batch (Avg. Loss 0.254, Accuracy 462.9): 100%|█████████████| 477/477 [00:29<00:00, 16.22it/s]
# test_batch (Avg. Loss 0.259, Accuracy 451.5): 100%|████████████████| 53/53 [00:00<00:00, 84.26it/s]
# train_batch (Avg. Loss 0.254, Accuracy 463.4): 100%|█████████████| 477/477 [00:29<00:00, 16.31it/s]
# test_batch (Avg. Loss 0.259, Accuracy 452.3): 100%|████████████████| 53/53 [00:00<00:00, 85.07it/s]
# train_batch (Avg. Loss 0.256, Accuracy 463.1): 100%|█████████████| 477/477 [00:29<00:00, 16.30it/s]
# test_batch (Avg. Loss 0.259, Accuracy 451.6): 100%|████████████████| 53/53 [00:00<00:00, 82.04it/s]
# train_batch (Avg. Loss 0.254, Accuracy 462.9): 100%|█████████████| 477/477 [00:28<00:00, 16.49it/s]
# test_batch (Avg. Loss 0.259, Accuracy 451.6): 100%|████████████████| 53/53 [00:00<00:00, 83.86it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 184
# train_batch (Avg. Loss 0.254, Accuracy 462.4): 100%|█████████████| 477/477 [00:28<00:00, 16.51it/s]
# test_batch (Avg. Loss 0.261, Accuracy 449.1): 100%|████████████████| 53/53 [00:00<00:00, 84.26it/s]
# train_batch (Avg. Loss 0.268, Accuracy 463.9): 100%|█████████████| 477/477 [00:28<00:00, 16.47it/s]
# test_batch (Avg. Loss 0.260, Accuracy 451.8): 100%|████████████████| 53/53 [00:00<00:00, 83.99it/s]
# train_batch (Avg. Loss 0.276, Accuracy 463.0): 100%|█████████████| 477/477 [00:32<00:00, 14.64it/s]
# test_batch (Avg. Loss 0.261, Accuracy 452.0): 100%|████████████████| 53/53 [00:00<00:00, 58.43it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 187
# train_batch (Avg. Loss 0.268, Accuracy 463.1): 100%|█████████████| 477/477 [00:36<00:00, 13.15it/s]
# test_batch (Avg. Loss 0.260, Accuracy 452.2): 100%|████████████████| 53/53 [00:00<00:00, 83.86it/s]
# train_batch (Avg. Loss 0.261, Accuracy 463.2): 100%|█████████████| 477/477 [00:29<00:00, 16.16it/s]
# test_batch (Avg. Loss 0.263, Accuracy 452.2): 100%|████████████████| 53/53 [00:00<00:00, 83.20it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 189
# train_batch (Avg. Loss 0.261, Accuracy 464.0): 100%|█████████████| 477/477 [00:29<00:00, 16.16it/s]
# test_batch (Avg. Loss 0.260, Accuracy 452.8): 100%|████████████████| 53/53 [00:00<00:00, 83.07it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 190
# --- EPOCH 191/200 ---
# train_batch (Avg. Loss 0.268, Accuracy 463.1): 100%|█████████████| 477/477 [00:30<00:00, 15.85it/s]
# test_batch (Avg. Loss 0.259, Accuracy 453.2): 100%|████████████████| 53/53 [00:00<00:00, 78.05it/s]
# train_batch (Avg. Loss 0.255, Accuracy 463.6): 100%|█████████████| 477/477 [00:29<00:00, 16.29it/s]
# test_batch (Avg. Loss 0.260, Accuracy 452.8): 100%|████████████████| 53/53 [00:00<00:00, 83.46it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 192
# train_batch (Avg. Loss 0.255, Accuracy 463.4): 100%|█████████████| 477/477 [00:29<00:00, 16.33it/s]
# test_batch (Avg. Loss 0.259, Accuracy 452.4): 100%|████████████████| 53/53 [00:00<00:00, 84.39it/s]
# train_batch (Avg. Loss 0.254, Accuracy 463.6): 100%|█████████████| 477/477 [00:28<00:00, 16.51it/s]
# test_batch (Avg. Loss 0.259, Accuracy 452.9): 100%|████████████████| 53/53 [00:00<00:00, 83.46it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 194
# train_batch (Avg. Loss 0.254, Accuracy 463.2): 100%|█████████████| 477/477 [00:29<00:00, 16.24it/s]
# test_batch (Avg. Loss 0.259, Accuracy 452.8): 100%|████████████████| 53/53 [00:00<00:00, 83.99it/s]
# train_batch (Avg. Loss 0.253, Accuracy 464.3): 100%|█████████████| 477/477 [00:29<00:00, 16.33it/s]
# test_batch (Avg. Loss 0.258, Accuracy 453.6): 100%|████████████████| 53/53 [00:00<00:00, 84.93it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 196
# train_batch (Avg. Loss 0.253, Accuracy 463.4): 100%|█████████████| 477/477 [00:29<00:00, 16.41it/s]
# test_batch (Avg. Loss 0.258, Accuracy 453.1): 100%|████████████████| 53/53 [00:00<00:00, 84.66it/s]
# train_batch (Avg. Loss 0.253, Accuracy 463.5): 100%|█████████████| 477/477 [00:29<00:00, 16.39it/s]
# test_batch (Avg. Loss 0.259, Accuracy 453.1): 100%|████████████████| 53/53 [00:00<00:00, 82.68it/s]
# train_batch (Avg. Loss 0.253, Accuracy 463.3): 100%|█████████████| 477/477 [00:29<00:00, 16.28it/s]
# test_batch (Avg. Loss 0.259, Accuracy 452.8): 100%|████████████████| 53/53 [00:00<00:00, 82.17it/s]
# --- EPOCH 200/200 ---
# train_batch (Avg. Loss 0.253, Accuracy 463.6): 100%|█████████████| 477/477 [00:30<00:00, 15.88it/s]
# test_batch (Avg. Loss 0.259, Accuracy 452.7): 100%|████████████████| 53/53 [00:00<00:00, 85.76it/s]
# *** Images Generated from best model:

# %% [markdown]
# ## Questions
# <a id=part2_7></a>

# %% [markdown]
# **TODO** Answer the following questions. Write your answers in the appropriate variables in the module `hw3/answers.py`.

# %%
from cs236781.answers import display_answer
import hw3.answers

# %% [markdown]
# ### Question 1
#
# What does the $\sigma^2$ hyperparameter (`x_sigma2` in the code) do? Explain the effect of low and high values.

# %%
display_answer(hw3.answers.part2_q1)
# Out:
# **Your answer:**
#
# When we calculate the reconstruction loss (= data loss) part of the total loss, we divide the MSE between
# the original image and the reconstructed image by ${\sigma}^2$ . Therefore, the hyperparameter ${\sigma}^2$ is
# used to adjust the weight we give to the reconstruction loss in the total loss.
#
# If the value of ${\sigma}^2$ is low, then the weight given to the data loss is high, and the consequence
# of that is that the output of the network (images reconstructed from latent space vector) will be more
# similar to the images that it was trained on.
#
# If the value of ${\sigma}^2$ is high, then the weight given to the data loss is low, and the consequence
# of that is that the output images will be more different from the training images, which means a more diverse
# space of output images, however if ${\sigma}^2$ is too small, then the output might not show the object that we
# wanted to represent.

# %% [markdown]
# ### Question 2
#
# 1. Explain the purpose of both parts of the VAE loss term - reconstruction loss and KL divergence loss.
# 2. How is the latent-space distribution affected by the KL loss term?
# 3. What's the benefit of this?

# %%
display_answer(hw3.answers.part2_q2)
# Out:
# **Your answer:**
#
# 1. The VAE loss function is the sum of 2 measures:
#     - a reconstruction loss term - the MSE between the input image and the output image
#     - a KL-divergence term - a measure of how each component's normal distribution in the latent space is different from $N(0,1)$.
#
# 2. The KL term in the loss function penalizes distributions that are different from $N(0,1)$ , and that leads to the distributions
# of the latent representations being close to the center of the latent space, and with deviations that are close to 1.
#
# 3. The benefit of the latent representation distributions being encouraged to be close to the center of the latent space is that
# when they are grouped, there is not much space between them, which means that the latent space can be considered continuous, and
# that allows us to sample any vector from the distribution $N(0,1)$ , decode it and receive a viable result image.
